# %%
import pandas as pd

# %%
# reference the data
data = "data/happiness_score_country_cleaned.csv"
#this .csv was downloaded from kaggle

# %%
# Read our Data file with the pandas library
df = pd.read_csv(data)

# %%
#view the data
df.head()
# Out:
#        Country  Happiness  GDP_per_capita  Social_support  Life_expectancy  \
# 0      Finland      7.842          10.775           0.954             72.0
# 1      Denmark      7.620          10.933           0.954             72.7
# 2  Switzerland      7.571          11.117           0.942             74.4
# 3      Iceland      7.554          10.878           0.983             73.0
# 4  Netherlands      7.464          10.932           0.942             72.4
#
#    Freedom  Generosity  Corruption  Dystopia  Contribution_GDP_per_capita  \
# 0    0.949      -0.098       0.186      2.43                        1.446
# 1    0.946       0.030       0.179      2.43                        1.502
# 2    0.919       0.025       0.292      2.43                        1.566
# 3    0.955       0.160       0.673      2.43                        1.482
# 4    0.913       0.175       0.338      2.43                        1.501
#
#    Contribution_Social_support  Contribution_Life_expectancy  \
# 0                        1.106                         0.741
# 1                        1.108                         0.763
# 2                        1.079                         0.816
# 3                        1.172                         0.772
# 4                        1.079                         0.753
#
#    Contribution_Freedom  Contribution_Generosity  Contribution_Corruption  \
# 0                 0.691                    0.124                    0.481
# 1                 0.686                    0.208                    0.485
# 2                 0.653                    0.204                    0.413
# 3                 0.698                    0.293                    0.170
# 4                 0.647                    0.302                    0.384
#
#    Contribution_Dystopia
# 0                  3.253
# 1                  2.868
# 2                  2.839
# 3                  2.967
# 4                  2.798

# %%
#drop irrelevant columns if needed
df = df.drop(columns = ['Regional indicator', 'Standard error of ladder score','upperwhisker','lowerwhisker'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16308\2435763090.py in <module>
#       1 #drop irrelevant columns
# ----> 2 df = df.drop(columns = ['Regional indicator', 'Standard error of ladder score','upperwhisker','lowerwhisker'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['Regional indicator', 'Standard error of ladder score', 'upperwhisker', 'lowerwhisker'] not found in axis"

# %%
#rename columns for database
df = df.rename(columns ={ 'Country name':'Country','Ladder score':'Happiness','Logged GDP per capita':'GDP_per_capita','Social support':'Social_support',
                    'Healthy life expectancy':'Life_expectancy','Freedom to make life choices':'Freedom','Perceptions of corruption':'Corruption'
                    ,'Ladder score in Dystopia':'Dystopia','Explained by: Log GDP per capita':'Contribution_GDP_per_capita',
                   'Explained by: Social support':'Contribution_Social_support','Explained by: Healthy life expectancy':'Contribution_Life_expectancy',
                   'Explained by: Generosity':'Contribution_Generosity','Explained by: Perceptions of corruption':'Contribution_Corruption',
                   'Dystopia + residual':'Contribution_Dystopia','Explained by: Freedom to make life choices':'Contribution_Freedom'})

# %%
#make country the index
df = df.set_index(list(df)[0])

# %%
#save clean .csv
df.to_csv('data/happiness_data_clean.csv')
