# %%
# Import the dependencies.
import numpy as np
import json

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify, render_template

# %%
#################################################
# Database Setup
#################################################
engine = create_engine("sqlite:////Users/JA/Desktop/Class_Projects_Data_Science_BC/EDDIES_3/Happiness-Dashboard/data/Happiness_PF.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()

# %%
# Save references to each table
Bands = Base.classes.Bands_2021
Happiness = Base.classes.Happiness_2021
Codes = Base.classes.Country_Codes

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
joined_results = session.query(Happiness, Bands, Codes).join(Bands, Happiness.Country == Bands.Country).join(Codes, Happiness.Country == Codes.Country).all() #filter(Happiness.Country == Bands.Country).filter(Happiness.Country == Codes.Country).all()

print(joined_results[0][1])
for result in joined_results:
    print(result[2].iso_a2)
# Out:
# <sqlalchemy.ext.automap.Bands_2021 object at 0x7ff33db29d30>
#  AF
#  AL
#  DZ
#  AR
#  AM
#  AU
#  AT
#  AZ
#  BH
#  BD
#  BY
#  BE
#  BO
#  BA
#  BW
#  BR
#  BG
#  MM
#  KH
#  CA
#  CL
#  CN
#  CO
#  CR
#  HR
#  CY
#  CZ
#  DK
#  DO
#  EC
#  EG
#  SV
#  EE
#  FI
#  FR
#  GE
#  DE
#  GR
#  GT
#  HN
#  HU
#  IS
#  IN
#  ID
#  IR
#  IQ
#  IE
#  IL
#  IT
#  JM
#  JP
#  JO
#  KZ
#  KE
#  KW
#  KG
#  LA
#  LV
#  LB
#  LY
#  LT
#  LU
#  MK
#  MG
#  MY
#  MV
#  MT
#  MU
#  MX
#  MD
#  MN
#  ME
#  MA
#  MZ
#  NA
#  NP
#  NL
#  NZ
#  NI
#  NO
#  PK
#  PA
#  PY
#  PE
#  PH
#  PL
#  PT
#  RO
#  RU
#  SA
#  RS
#  SG
#  SK
#  SI
#  ZA
#  KR
#  ES
#  LK
#  SE
#  CH
#  TJ
#  TH
#  TN
#  TR
#  TM
#  UG
#  UA
#  AE
#  GB
#  US
#  UY
#  UZ
#  VE
#  VN
#  ZW

# %%
# Return a list of all happiness scores by country
# Query all happiness data
scores_results = session.query(Happiness.Country, Happiness.Happiness).all()
print(scores_results)

# %%
bands_results = session.query(Bands.Country, Bands.Bands).all()
bands_results

# %%
happiness_results = session.query(Happiness.Country, Happiness.Happiness, Happiness.GDP_per_capita, Happiness.Social_support, Happiness.Life_expectancy, Happiness.Freedom, Happiness.Generosity, Happiness.Corruption, Happiness.Dystopia, Bands.Bands).all()
happiness_results

# %%
happiness_data_list = []

for result in happiness_results:
    country = result[0]
    happiness_score = result[1]
    gdp = result[2]
    social_support = result[3]
    life_expectancy = result[4]
    freedom = result[5]
    generosity = result[6]
    corruption = result[7]
    dystopia = result[8]

    happiness_data = [{
        "country": country,
        "happiness score": happiness_score,
        "gdp": gdp,
        "social_support": social_support,
        "life_expectancy": life_expectancy,
        "freedom": freedom,
        "generosity": generosity,
        "corruption": corruption,
        "dystopia": dystopia
        }]
    happiness_data_list.append(happiness_data)

# %%
contribution_results = session.query(Happiness.Country, Happiness.Contribution_GDP_per_capita, Happiness.Contribution_Social_support, Happiness.Contribution_Life_expectancy, Happiness.Contribution_Freedom, Happiness.Contribution_Generosity, Happiness.Contribution_Corruption, Happiness.Contribution_Dystopia).all()
contribution_results

# %%
contribution_data_list = []

for result in contribution_results:
    country = result[0]
    contribution_gdp = result[1]
    contribution_social_support = result[2]
    contribution_life_expectancy = result[3]
    contribution_freedom = result[4]
    contribution_generosity = result[5]
    contribution_corruption = result[6]
    contribution_dystopia = result[7]

    contribution_data = [{
        "country": country,
        "contribution_gdp": contribution_gdp,
        "contribution_social_support": contribution_social_support,
        "contribution_life_expectancy": contribution_life_expectancy,
        "contribution_freedom": contribution_freedom,
        "contribution_generosity": contribution_generosity,
        "contribution_corruption": contribution_corruption,
        "contribution_dystopia": contribution_dystopia
        }]

    contribution_data_list.append(contribution_data)
contribution_data_list

# %%
codes_results = session.query(Codes.iso_a2, Codes.iso_a3)

# %%
for result in codes_results:
    print(result)

# %%
# joined_results = session.query(Happiness, Bands, Codes).join(Bands, Happiness.Country == Bands.Country).join(Codes, Happiness.Country == Codes.Country).all() #filter(Happiness.Country == Bands.Country).filter(Happiness.Country == Codes.Country).all()    
# happiness_results = session.query(Happiness.Country, Happiness.Happiness, Happiness.GDP_per_capita, Happiness.Social_support, Happiness.Life_expectancy, Happiness.Freedom, Happiness.Generosity, Happiness.Corruption, Happiness.Dystopia, Happiness.Contribution_GDP_per_capita, Happiness.Contribution_Social_support, Happiness.Contribution_Life_expectancy, Happiness.Contribution_Freedom, Happiness.Contribution_Generosity, Happiness.Contribution_Corruption, Happiness.Contribution_Dystopia, Bands.Metal_bands_per_100000_people, Bands.Bands, Bands.Population).all()

happiness_data_list2 = []

for result in joined_results:
    country = result[0].Country
    happiness_score = result[0].Happiness
    gdp = result[0].GDP_per_capita
    social_support = result[0].Social_support
    life_expectancy = result[0].Life_expectancy
    freedom = result[0].Freedom
    generosity = result[0].Generosity
    corruption = result[0].Corruption
    dystopia = result[0].Dystopia
    contribution_gdp = result[0].Contribution_GDP_per_capita
    contribution_social_support = result[0].Contribution_Social_support
    contribution_life_expectancy = result[0].Contribution_Life_expectancy
    contribution_freedom = result[0].Contribution_Freedom
    contribution_generosity = result[0].Contribution_Generosity
    contribution_corruption = result[0].Contribution_Corruption
    contribution_dystopia = result[0].Contribution_Dystopia
    metal_bands_per_100000_people = result[1].Metal_bands_per_100000_people
    bands = result[1].Bands
    population = result[1].Population
    iso_a2 = result[2].iso_a2
    iso_a3 = result[2].iso_a3
    
    happiness_data2 = {
        "country": country,
        "happiness score": happiness_score,
        "gdp": gdp,
        "social_support": social_support,
        "life_expectancy": life_expectancy,
        "freedom": freedom,
        "generosity": generosity,
        "corruption": corruption,
        "dystopia": dystopia,
        "contribution_gdp": contribution_gdp,
        "contribution_social_support": contribution_social_support,
        "contribution_life_expectancy": contribution_life_expectancy,
        "contribution_freedom": contribution_freedom,
        "contribution_generosity": contribution_generosity,
        "contribution_corruption": contribution_corruption,
        "contribution_dystopia": contribution_dystopia,
        "metal_bands_per_100000_people": metal_bands_per_100000_people,
        "bands": bands,
        "population": population,
        "iso_a2": iso_a2,
        "iso_a3": iso_a3
        }

    happiness_data_list2.append(happiness_data2)
happiness_data_list2
# Out:
# [{'country': 'Afghanistan',
#   'happiness score': 2.523,
#   'gdp': 7.695,
#   'social_support': 0.463,
#   'life_expectancy': 52.493,
#   'freedom': 0.382,
#   'generosity': -0.102,
#   'corruption': 0.924,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.37,
#   'contribution_social_support': 0.0,
#   'contribution_life_expectancy': 0.126,
#   'contribution_freedom': 0.0,
#   'contribution_generosity': 0.122,
#   'contribution_corruption': 0.01,
#   'contribution_dystopia': 1.895,
#   'metal_bands_per_100000_people': 0.005,
#   'bands': '2',
#   'population': '37,466,414',
#   'iso_a2': ' AF',
#   'iso_a3': ' AFG'},
#  {'country': 'Albania',
#   'happiness score': 5.117,
#   'gdp': 9.52,
#   'social_support': 0.697,
#   'life_expectancy': 68.999,
#   'freedom': 0.785,
#   'generosity': -0.03,
#   'corruption': 0.901,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.008,
#   'contribution_social_support': 0.529,
#   'contribution_life_expectancy': 0.646,
#   'contribution_freedom': 0.491,
#   'contribution_generosity': 0.168,
#   'contribution_corruption': 0.024,
#   'contribution_dystopia': 2.25,
#   'metal_bands_per_100000_people': 0.227,
#   'bands': '7',
#   'population': '3,088,385',
#   'iso_a2': ' AL',
#   'iso_a3': ' ALB'},
#  {'country': 'Algeria',
#   'happiness score': 4.887,
#   'gdp': 9.342,
#   'social_support': 0.802,
#   'life_expectancy': 66.005,
#   'freedom': 0.48,
#   'generosity': -0.067,
#   'corruption': 0.752,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.946,
#   'contribution_social_support': 0.765,
#   'contribution_life_expectancy': 0.552,
#   'contribution_freedom': 0.119,
#   'contribution_generosity': 0.144,
#   'contribution_corruption': 0.12,
#   'contribution_dystopia': 2.242,
#   'metal_bands_per_100000_people': 0.037,
#   'bands': '16',
#   'population': '43,576,691',
#   'iso_a2': ' DZ',
#   'iso_a3': ' DZA'},
#  {'country': 'Argentina',
#   'happiness score': 5.929,
#   'gdp': 9.962,
#   'social_support': 0.898,
#   'life_expectancy': 69.0,
#   'freedom': 0.828,
#   'generosity': -0.182,
#   'corruption': 0.834,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.162,
#   'contribution_social_support': 0.98,
#   'contribution_life_expectancy': 0.646,
#   'contribution_freedom': 0.544,
#   'contribution_generosity': 0.069,
#   'contribution_corruption': 0.067,
#   'contribution_dystopia': 2.461,
#   'metal_bands_per_100000_people': 4.158,
#   'bands': '1,907',
#   'population': '45,864,941',
#   'iso_a2': ' AR',
#   'iso_a3': ' ARG'},
#  {'country': 'Armenia',
#   'happiness score': 5.283,
#   'gdp': 9.487,
#   'social_support': 0.799,
#   'life_expectancy': 67.055,
#   'freedom': 0.825,
#   'generosity': -0.168,
#   'corruption': 0.629,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.996,
#   'contribution_social_support': 0.758,
#   'contribution_life_expectancy': 0.585,
#   'contribution_freedom': 0.54,
#   'contribution_generosity': 0.079,
#   'contribution_corruption': 0.198,
#   'contribution_dystopia': 2.127,
#   'metal_bands_per_100000_people': 0.631,
#   'bands': '19',
#   'population': '3,011,609',
#   'iso_a2': ' AM',
#   'iso_a3': ' ARM'},
#  {'country': 'Australia',
#   'happiness score': 7.183,
#   'gdp': 10.796,
#   'social_support': 0.94,
#   'life_expectancy': 73.9,
#   'freedom': 0.914,
#   'generosity': 0.159,
#   'corruption': 0.442,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.453,
#   'contribution_social_support': 1.076,
#   'contribution_life_expectancy': 0.801,
#   'contribution_freedom': 0.647,
#   'contribution_generosity': 0.291,
#   'contribution_corruption': 0.317,
#   'contribution_dystopia': 2.598,
#   'metal_bands_per_100000_people': 5.986,
#   'bands': '1,545',
#   'population': '25,809,973',
#   'iso_a2': ' AU',
#   'iso_a3': ' AUS'},
#  {'country': 'Austria',
#   'happiness score': 7.268,
#   'gdp': 10.906,
#   'social_support': 0.934,
#   'life_expectancy': 73.3,
#   'freedom': 0.908,
#   'generosity': 0.042,
#   'corruption': 0.481,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.492,
#   'contribution_social_support': 1.062,
#   'contribution_life_expectancy': 0.782,
#   'contribution_freedom': 0.64,
#   'contribution_generosity': 0.215,
#   'contribution_corruption': 0.292,
#   'contribution_dystopia': 2.784,
#   'metal_bands_per_100000_people': 7.473,
#   'bands': '664',
#   'population': '8,884,864',
#   'iso_a2': ' AT',
#   'iso_a3': ' AUT'},
#  {'country': 'Azerbaijan',
#   'happiness score': 5.171,
#   'gdp': 9.569,
#   'social_support': 0.836,
#   'life_expectancy': 65.656,
#   'freedom': 0.814,
#   'generosity': -0.223,
#   'corruption': 0.506,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.025,
#   'contribution_social_support': 0.841,
#   'contribution_life_expectancy': 0.541,
#   'contribution_freedom': 0.526,
#   'contribution_generosity': 0.043,
#   'contribution_corruption': 0.276,
#   'contribution_dystopia': 1.919,
#   'metal_bands_per_100000_people': 0.088,
#   'bands': '9',
#   'population': '10,282,283',
#   'iso_a2': ' AZ',
#   'iso_a3': ' AZE'},
#  {'country': 'Bahrain',
#   'happiness score': 6.647,
#   'gdp': 10.669,
#   'social_support': 0.862,
#   'life_expectancy': 69.495,
#   'freedom': 0.925,
#   'generosity': 0.089,
#   'corruption': 0.722,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.409,
#   'contribution_social_support': 0.899,
#   'contribution_life_expectancy': 0.662,
#   'contribution_freedom': 0.661,
#   'contribution_generosity': 0.246,
#   'contribution_corruption': 0.139,
#   'contribution_dystopia': 2.631,
#   'metal_bands_per_100000_people': 0.393,
#   'bands': '6',
#   'population': '1,526,929',
#   'iso_a2': ' BH',
#   'iso_a3': ' BHR'},
#  {'country': 'Bangladesh',
#   'happiness score': 5.025,
#   'gdp': 8.454,
#   'social_support': 0.693,
#   'life_expectancy': 64.8,
#   'freedom': 0.877,
#   'generosity': -0.041,
#   'corruption': 0.682,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.635,
#   'contribution_social_support': 0.52,
#   'contribution_life_expectancy': 0.514,
#   'contribution_freedom': 0.603,
#   'contribution_generosity': 0.161,
#   'contribution_corruption': 0.164,
#   'contribution_dystopia': 2.427,
#   'metal_bands_per_100000_people': 0.04,
#   'bands': '65',
#   'population': '164,098,818',
#   'iso_a2': ' BD',
#   'iso_a3': ' BGD'},
#  {'country': 'Belarus',
#   'happiness score': 5.534,
#   'gdp': 9.853,
#   'social_support': 0.91,
#   'life_expectancy': 66.253,
#   'freedom': 0.65,
#   'generosity': -0.18,
#   'corruption': 0.627,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.124,
#   'contribution_social_support': 1.007,
#   'contribution_life_expectancy': 0.56,
#   'contribution_freedom': 0.326,
#   'contribution_generosity': 0.07,
#   'contribution_corruption': 0.199,
#   'contribution_dystopia': 2.247,
#   'metal_bands_per_100000_people': 3.103,
#   'bands': '293',
#   'population': '9,441,842',
#   'iso_a2': ' BY',
#   'iso_a3': ' BLR'},
#  {'country': 'Belgium',
#   'happiness score': 6.834,
#   'gdp': 10.823,
#   'social_support': 0.906,
#   'life_expectancy': 72.199,
#   'freedom': 0.783,
#   'generosity': -0.153,
#   'corruption': 0.646,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.463,
#   'contribution_social_support': 0.998,
#   'contribution_life_expectancy': 0.747,
#   'contribution_freedom': 0.489,
#   'contribution_generosity': 0.088,
#   'contribution_corruption': 0.187,
#   'contribution_dystopia': 2.862,
#   'metal_bands_per_100000_people': 5.654,
#   'bands': '666',
#   'population': '11,778,842',
#   'iso_a2': ' BE',
#   'iso_a3': ' BEL'},
#  {'country': 'Bolivia',
#   'happiness score': 5.716,
#   'gdp': 9.046,
#   'social_support': 0.81,
#   'life_expectancy': 63.901,
#   'freedom': 0.875,
#   'generosity': -0.077,
#   'corruption': 0.839,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.842,
#   'contribution_social_support': 0.782,
#   'contribution_life_expectancy': 0.486,
#   'contribution_freedom': 0.6,
#   'contribution_generosity': 0.138,
#   'contribution_corruption': 0.064,
#   'contribution_dystopia': 2.805,
#   'metal_bands_per_100000_people': 2.067,
#   'bands': '243',
#   'population': '11,758,869',
#   'iso_a2': ' BO',
#   'iso_a3': ' BOL'},
#  {'country': 'Bosnia and Herzegovina',
#   'happiness score': 5.813,
#   'gdp': 9.59,
#   'social_support': 0.87,
#   'life_expectancy': 68.098,
#   'freedom': 0.706,
#   'generosity': 0.113,
#   'corruption': 0.931,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.032,
#   'contribution_social_support': 0.919,
#   'contribution_life_expectancy': 0.618,
#   'contribution_freedom': 0.395,
#   'contribution_generosity': 0.261,
#   'contribution_corruption': 0.005,
#   'contribution_dystopia': 2.583,
#   'metal_bands_per_100000_people': 2.248,
#   'bands': '86',
#   'population': '3,824,782',
#   'iso_a2': ' BA',
#   'iso_a3': ' BIH'},
#  {'country': 'Botswana',
#   'happiness score': 3.467,
#   'gdp': 9.782,
#   'social_support': 0.784,
#   'life_expectancy': 59.269,
#   'freedom': 0.824,
#   'generosity': -0.246,
#   'corruption': 0.801,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.099,
#   'contribution_social_support': 0.724,
#   'contribution_life_expectancy': 0.34,
#   'contribution_freedom': 0.539,
#   'contribution_generosity': 0.027,
#   'contribution_corruption': 0.088,
#   'contribution_dystopia': 0.648,
#   'metal_bands_per_100000_people': 0.298,
#   'bands': '7',
#   'population': '2,350,667',
#   'iso_a2': ' BW',
#   'iso_a3': ' BWA'},
#  {'country': 'Brazil',
#   'happiness score': 6.33,
#   'gdp': 9.577,
#   'social_support': 0.882,
#   'life_expectancy': 66.601,
#   'freedom': 0.804,
#   'generosity': -0.071,
#   'corruption': 0.756,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.028,
#   'contribution_social_support': 0.944,
#   'contribution_life_expectancy': 0.571,
#   'contribution_freedom': 0.514,
#   'contribution_generosity': 0.142,
#   'contribution_corruption': 0.117,
#   'contribution_dystopia': 3.015,
#   'metal_bands_per_100000_people': 1.955,
#   'bands': '4,173',
#   'population': '213,445,417',
#   'iso_a2': ' BR',
#   'iso_a3': ' BRA'},
#  {'country': 'Bulgaria',
#   'happiness score': 5.266,
#   'gdp': 10.016,
#   'social_support': 0.931,
#   'life_expectancy': 67.0,
#   'freedom': 0.788,
#   'generosity': -0.096,
#   'corruption': 0.932,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.181,
#   'contribution_social_support': 1.055,
#   'contribution_life_expectancy': 0.583,
#   'contribution_freedom': 0.494,
#   'contribution_generosity': 0.125,
#   'contribution_corruption': 0.005,
#   'contribution_dystopia': 1.823,
#   'metal_bands_per_100000_people': 2.934,
#   'bands': '203',
#   'population': '6,919,180',
#   'iso_a2': ' BG',
#   'iso_a3': ' BGR'},
#  {'country': 'Myanmar',
#   'happiness score': 4.426,
#   'gdp': 8.541,
#   'social_support': 0.779,
#   'life_expectancy': 59.302,
#   'freedom': 0.876,
#   'generosity': 0.509,
#   'corruption': 0.66,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.666,
#   'contribution_social_support': 0.713,
#   'contribution_life_expectancy': 0.341,
#   'contribution_freedom': 0.601,
#   'contribution_generosity': 0.52,
#   'contribution_corruption': 0.178,
#   'contribution_dystopia': 1.407,
#   'metal_bands_per_100000_people': 0.016,
#   'bands': '9',
#   'population': '57,069,099',
#   'iso_a2': ' MM',
#   'iso_a3': ' MMR'},
#  {'country': 'Cambodia',
#   'happiness score': 4.83,
#   'gdp': 8.36,
#   'social_support': 0.765,
#   'life_expectancy': 62.0,
#   'freedom': 0.959,
#   'generosity': 0.034,
#   'corruption': 0.843,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.603,
#   'contribution_social_support': 0.68,
#   'contribution_life_expectancy': 0.426,
#   'contribution_freedom': 0.702,
#   'contribution_generosity': 0.21,
#   'contribution_corruption': 0.061,
#   'contribution_dystopia': 2.148,
#   'metal_bands_per_100000_people': 0.012,
#   'bands': '2',
#   'population': '17,304,363',
#   'iso_a2': ' KH',
#   'iso_a3': ' KHM'},
#  {'country': 'Canada',
#   'happiness score': 7.103,
#   'gdp': 10.776,
#   'social_support': 0.926,
#   'life_expectancy': 73.8,
#   'freedom': 0.915,
#   'generosity': 0.089,
#   'corruption': 0.415,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.447,
#   'contribution_social_support': 1.044,
#   'contribution_life_expectancy': 0.798,
#   'contribution_freedom': 0.648,
#   'contribution_generosity': 0.246,
#   'contribution_corruption': 0.335,
#   'contribution_dystopia': 2.585,
#   'metal_bands_per_100000_people': 7.263,
#   'bands': '2,756',
#   'population': '37,943,231',
#   'iso_a2': ' CA',
#   'iso_a3': ' CAN'},
#  {'country': 'Chile',
#   'happiness score': 6.172,
#   'gdp': 10.071,
#   'social_support': 0.882,
#   'life_expectancy': 70.0,
#   'freedom': 0.742,
#   'generosity': -0.044,
#   'corruption': 0.83,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.2,
#   'contribution_social_support': 0.946,
#   'contribution_life_expectancy': 0.678,
#   'contribution_freedom': 0.438,
#   'contribution_generosity': 0.159,
#   'contribution_corruption': 0.07,
#   'contribution_dystopia': 2.682,
#   'metal_bands_per_100000_people': 11.449,
#   'bands': '2,096',
#   'population': '18,307,925',
#   'iso_a2': ' CL',
#   'iso_a3': ' CHL'},
#  {'country': 'China',
#   'happiness score': 5.339,
#   'gdp': 9.673,
#   'social_support': 0.811,
#   'life_expectancy': 69.593,
#   'freedom': 0.904,
#   'generosity': -0.146,
#   'corruption': 0.755,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.061,
#   'contribution_social_support': 0.785,
#   'contribution_life_expectancy': 0.665,
#   'contribution_freedom': 0.636,
#   'contribution_generosity': 0.093,
#   'contribution_corruption': 0.117,
#   'contribution_dystopia': 1.982,
#   'metal_bands_per_100000_people': 0.02,
#   'bands': '284',
#   'population': '1,397,897,720',
#   'iso_a2': ' CN',
#   'iso_a3': ' CHN'},
#  {'country': 'Colombia',
#   'happiness score': 6.012,
#   'gdp': 9.557,
#   'social_support': 0.847,
#   'life_expectancy': 68.001,
#   'freedom': 0.837,
#   'generosity': -0.135,
#   'corruption': 0.841,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.021,
#   'contribution_social_support': 0.866,
#   'contribution_life_expectancy': 0.615,
#   'contribution_freedom': 0.554,
#   'contribution_generosity': 0.1,
#   'contribution_corruption': 0.063,
#   'contribution_dystopia': 2.794,
#   'metal_bands_per_100000_people': 2.961,
#   'bands': '1,491',
#   'population': '50,355,650',
#   'iso_a2': ' CO',
#   'iso_a3': ' COL'},
#  {'country': 'Costa Rica',
#   'happiness score': 7.069,
#   'gdp': 9.88,
#   'social_support': 0.891,
#   'life_expectancy': 71.4,
#   'freedom': 0.934,
#   'generosity': -0.126,
#   'corruption': 0.809,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.134,
#   'contribution_social_support': 0.966,
#   'contribution_life_expectancy': 0.722,
#   'contribution_freedom': 0.673,
#   'contribution_generosity': 0.105,
#   'contribution_corruption': 0.083,
#   'contribution_dystopia': 3.387,
#   'metal_bands_per_100000_people': 4.562,
#   'bands': '235',
#   'population': '5,151,140',
#   'iso_a2': ' CR',
#   'iso_a3': ' CRI'},
#  {'country': 'Croatia',
#   'happiness score': 5.882,
#   'gdp': 10.217,
#   'social_support': 0.924,
#   'life_expectancy': 70.799,
#   'freedom': 0.754,
#   'generosity': -0.118,
#   'corruption': 0.939,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.251,
#   'contribution_social_support': 1.039,
#   'contribution_life_expectancy': 0.703,
#   'contribution_freedom': 0.453,
#   'contribution_generosity': 0.111,
#   'contribution_corruption': 0.0,
#   'contribution_dystopia': 2.325,
#   'metal_bands_per_100000_people': 5.892,
#   'bands': '248',
#   'population': '4,208,973',
#   'iso_a2': ' HR',
#   'iso_a3': ' HRV'},
#  {'country': 'Cyprus',
#   'happiness score': 6.223,
#   'gdp': 10.576,
#   'social_support': 0.802,
#   'life_expectancy': 73.898,
#   'freedom': 0.763,
#   'generosity': -0.015,
#   'corruption': 0.844,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.377,
#   'contribution_social_support': 0.765,
#   'contribution_life_expectancy': 0.801,
#   'contribution_freedom': 0.464,
#   'contribution_generosity': 0.178,
#   'contribution_corruption': 0.061,
#   'contribution_dystopia': 2.578,
#   'metal_bands_per_100000_people': 4.058,
#   'bands': '52',
#   'population': '1,281,506',
#   'iso_a2': ' CY',
#   'iso_a3': ' CYP'},
#  {'country': 'Czech Republic',
#   'happiness score': 6.965,
#   'gdp': 10.556,
#   'social_support': 0.947,
#   'life_expectancy': 70.807,
#   'freedom': 0.858,
#   'generosity': -0.208,
#   'corruption': 0.868,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.37,
#   'contribution_social_support': 1.09,
#   'contribution_life_expectancy': 0.703,
#   'contribution_freedom': 0.58,
#   'contribution_generosity': 0.052,
#   'contribution_corruption': 0.046,
#   'contribution_dystopia': 3.124,
#   'metal_bands_per_100000_people': 9.007,
#   'bands': '964',
#   'population': '10,702,596',
#   'iso_a2': ' CZ',
#   'iso_a3': ' CZE'},
#  {'country': 'Denmark',
#   'happiness score': 7.62,
#   'gdp': 10.933,
#   'social_support': 0.954,
#   'life_expectancy': 72.7,
#   'freedom': 0.946,
#   'generosity': 0.03,
#   'corruption': 0.179,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.502,
#   'contribution_social_support': 1.108,
#   'contribution_life_expectancy': 0.763,
#   'contribution_freedom': 0.686,
#   'contribution_generosity': 0.208,
#   'contribution_corruption': 0.485,
#   'contribution_dystopia': 2.868,
#   'metal_bands_per_100000_people': 8.482,
#   'bands': '500',
#   'population': '5,894,687',
#   'iso_a2': ' DK',
#   'iso_a3': ' DNK'},
#  {'country': 'Dominican Republic',
#   'happiness score': 5.545,
#   'gdp': 9.802,
#   'social_support': 0.853,
#   'life_expectancy': 66.102,
#   'freedom': 0.86,
#   'generosity': -0.133,
#   'corruption': 0.714,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.106,
#   'contribution_social_support': 0.879,
#   'contribution_life_expectancy': 0.555,
#   'contribution_freedom': 0.581,
#   'contribution_generosity': 0.101,
#   'contribution_corruption': 0.144,
#   'contribution_dystopia': 2.178,
#   'metal_bands_per_100000_people': 0.293,
#   'bands': '31',
#   'population': '10,597,348',
#   'iso_a2': ' DO',
#   'iso_a3': ' DOM'},
#  {'country': 'Ecuador',
#   'happiness score': 5.764,
#   'gdp': 9.313,
#   'social_support': 0.821,
#   'life_expectancy': 68.8,
#   'freedom': 0.842,
#   'generosity': -0.124,
#   'corruption': 0.843,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.935,
#   'contribution_social_support': 0.806,
#   'contribution_life_expectancy': 0.64,
#   'contribution_freedom': 0.56,
#   'contribution_generosity': 0.107,
#   'contribution_corruption': 0.062,
#   'contribution_dystopia': 2.653,
#   'metal_bands_per_100000_people': 2.75,
#   'bands': '470',
#   'population': '17,093,159',
#   'iso_a2': ' EC',
#   'iso_a3': ' ECU'},
#  {'country': 'Egypt',
#   'happiness score': 4.283,
#   'gdp': 9.367,
#   'social_support': 0.75,
#   'life_expectancy': 61.998,
#   'freedom': 0.749,
#   'generosity': -0.182,
#   'corruption': 0.795,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.954,
#   'contribution_social_support': 0.647,
#   'contribution_life_expectancy': 0.426,
#   'contribution_freedom': 0.446,
#   'contribution_generosity': 0.069,
#   'contribution_corruption': 0.092,
#   'contribution_dystopia': 1.648,
#   'metal_bands_per_100000_people': 0.039,
#   'bands': '41',
#   'population': '106,437,241',
#   'iso_a2': ' EG',
#   'iso_a3': ' EGY'},
#  {'country': 'El Salvador',
#   'happiness score': 6.061,
#   'gdp': 9.054,
#   'social_support': 0.762,
#   'life_expectancy': 66.402,
#   'freedom': 0.888,
#   'generosity': -0.11,
#   'corruption': 0.688,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.845,
#   'contribution_social_support': 0.675,
#   'contribution_life_expectancy': 0.565,
#   'contribution_freedom': 0.615,
#   'contribution_generosity': 0.116,
#   'contribution_corruption': 0.16,
#   'contribution_dystopia': 3.085,
#   'metal_bands_per_100000_people': 1.471,
#   'bands': '96',
#   'population': '6,528,135',
#   'iso_a2': ' SV',
#   'iso_a3': ' SLV'},
#  {'country': 'Estonia',
#   'happiness score': 6.189,
#   'gdp': 10.481,
#   'social_support': 0.941,
#   'life_expectancy': 68.8,
#   'freedom': 0.909,
#   'generosity': -0.106,
#   'corruption': 0.527,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.344,
#   'contribution_social_support': 1.079,
#   'contribution_life_expectancy': 0.64,
#   'contribution_freedom': 0.641,
#   'contribution_generosity': 0.119,
#   'contribution_corruption': 0.263,
#   'contribution_dystopia': 2.103,
#   'metal_bands_per_100000_people': 11.065,
#   'bands': '135',
#   'population': '1,220,042',
#   'iso_a2': ' EE',
#   'iso_a3': ' EST'},
#  {'country': 'Finland',
#   'happiness score': 7.842,
#   'gdp': 10.775,
#   'social_support': 0.954,
#   'life_expectancy': 72.0,
#   'freedom': 0.949,
#   'generosity': -0.098,
#   'corruption': 0.186,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.446,
#   'contribution_social_support': 1.106,
#   'contribution_life_expectancy': 0.741,
#   'contribution_freedom': 0.691,
#   'contribution_generosity': 0.124,
#   'contribution_corruption': 0.481,
#   'contribution_dystopia': 3.253,
#   'metal_bands_per_100000_people': 42.613,
#   'bands': '2,381',
#   'population': '5,587,442',
#   'iso_a2': ' FI',
#   'iso_a3': ' FIN'},
#  {'country': 'France',
#   'happiness score': 6.69,
#   'gdp': 10.704,
#   'social_support': 0.942,
#   'life_expectancy': 74.0,
#   'freedom': 0.822,
#   'generosity': -0.147,
#   'corruption': 0.571,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.421,
#   'contribution_social_support': 1.081,
#   'contribution_life_expectancy': 0.804,
#   'contribution_freedom': 0.536,
#   'contribution_generosity': 0.092,
#   'contribution_corruption': 0.235,
#   'contribution_dystopia': 2.521,
#   'metal_bands_per_100000_people': 4.259,
#   'bands': '2,900',
#   'population': '68,084,217',
#   'iso_a2': ' FR',
#   'iso_a3': ' FRA'},
#  {'country': 'Georgia',
#   'happiness score': 4.891,
#   'gdp': 9.585,
#   'social_support': 0.671,
#   'life_expectancy': 64.3,
#   'freedom': 0.783,
#   'generosity': -0.238,
#   'corruption': 0.655,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.03,
#   'contribution_social_support': 0.47,
#   'contribution_life_expectancy': 0.498,
#   'contribution_freedom': 0.488,
#   'contribution_generosity': 0.032,
#   'contribution_corruption': 0.181,
#   'contribution_dystopia': 2.191,
#   'metal_bands_per_100000_people': 0.466,
#   'bands': '23',
#   'population': '4,933,674',
#   'iso_a2': ' GE',
#   'iso_a3': ' GEO'},
#  {'country': 'Germany',
#   'happiness score': 7.155,
#   'gdp': 10.873,
#   'social_support': 0.903,
#   'life_expectancy': 72.5,
#   'freedom': 0.875,
#   'generosity': 0.011,
#   'corruption': 0.46,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.48,
#   'contribution_social_support': 0.993,
#   'contribution_life_expectancy': 0.757,
#   'contribution_freedom': 0.6,
#   'contribution_generosity': 0.195,
#   'contribution_corruption': 0.306,
#   'contribution_dystopia': 2.824,
#   'metal_bands_per_100000_people': 7.166,
#   'bands': '5,726',
#   'population': '79,903,481',
#   'iso_a2': ' DE',
#   'iso_a3': ' DEU'},
#  {'country': 'Greece',
#   'happiness score': 5.723,
#   'gdp': 10.279,
#   'social_support': 0.823,
#   'life_expectancy': 72.6,
#   'freedom': 0.582,
#   'generosity': -0.288,
#   'corruption': 0.823,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.273,
#   'contribution_social_support': 0.811,
#   'contribution_life_expectancy': 0.76,
#   'contribution_freedom': 0.243,
#   'contribution_generosity': 0.0,
#   'contribution_corruption': 0.074,
#   'contribution_dystopia': 2.561,
#   'metal_bands_per_100000_people': 11.694,
#   'bands': '1,236',
#   'population': '10,569,703',
#   'iso_a2': ' GR',
#   'iso_a3': ' GRC'},
#  {'country': 'Guatemala',
#   'happiness score': 6.435,
#   'gdp': 9.053,
#   'social_support': 0.813,
#   'life_expectancy': 64.958,
#   'freedom': 0.906,
#   'generosity': -0.038,
#   'corruption': 0.775,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.845,
#   'contribution_social_support': 0.79,
#   'contribution_life_expectancy': 0.519,
#   'contribution_freedom': 0.638,
#   'contribution_generosity': 0.163,
#   'contribution_corruption': 0.105,
#   'contribution_dystopia': 3.375,
#   'metal_bands_per_100000_people': 0.649,
#   'bands': '113',
#   'population': '17,422,821',
#   'iso_a2': ' GT',
#   'iso_a3': ' GTM'},
#  {'country': 'Honduras',
#   'happiness score': 5.919,
#   'gdp': 8.648,
#   'social_support': 0.812,
#   'life_expectancy': 67.3,
#   'freedom': 0.857,
#   'generosity': 0.081,
#   'corruption': 0.809,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.703,
#   'contribution_social_support': 0.787,
#   'contribution_life_expectancy': 0.593,
#   'contribution_freedom': 0.578,
#   'contribution_generosity': 0.241,
#   'contribution_corruption': 0.083,
#   'contribution_dystopia': 2.934,
#   'metal_bands_per_100000_people': 0.535,
#   'bands': '50',
#   'population': '9,346,277',
#   'iso_a2': ' HN',
#   'iso_a3': ' HND'},
#  {'country': 'Hungary',
#   'happiness score': 5.992,
#   'gdp': 10.358,
#   'social_support': 0.943,
#   'life_expectancy': 68.0,
#   'freedom': 0.755,
#   'generosity': -0.186,
#   'corruption': 0.876,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.301,
#   'contribution_social_support': 1.083,
#   'contribution_life_expectancy': 0.615,
#   'contribution_freedom': 0.454,
#   'contribution_generosity': 0.067,
#   'contribution_corruption': 0.04,
#   'contribution_dystopia': 2.432,
#   'metal_bands_per_100000_people': 6.209,
#   'bands': '604',
#   'population': '9,728,337',
#   'iso_a2': ' HU',
#   'iso_a3': ' HUN'},
#  {'country': 'Iceland',
#   'happiness score': 7.554,
#   'gdp': 10.878,
#   'social_support': 0.983,
#   'life_expectancy': 73.0,
#   'freedom': 0.955,
#   'generosity': 0.16,
#   'corruption': 0.673,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.482,
#   'contribution_social_support': 1.172,
#   'contribution_life_expectancy': 0.772,
#   'contribution_freedom': 0.698,
#   'contribution_generosity': 0.293,
#   'contribution_corruption': 0.17,
#   'contribution_dystopia': 2.967,
#   'metal_bands_per_100000_people': 31.9,
#   'bands': '113',
#   'population': '354,234',
#   'iso_a2': ' IS',
#   'iso_a3': ' ISL'},
#  {'country': 'India',
#   'happiness score': 3.819,
#   'gdp': 8.755,
#   'social_support': 0.603,
#   'life_expectancy': 60.633,
#   'freedom': 0.893,
#   'generosity': 0.089,
#   'corruption': 0.774,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.741,
#   'contribution_social_support': 0.316,
#   'contribution_life_expectancy': 0.383,
#   'contribution_freedom': 0.622,
#   'contribution_generosity': 0.246,
#   'contribution_corruption': 0.106,
#   'contribution_dystopia': 1.405,
#   'metal_bands_per_100000_people': 0.015,
#   'bands': '196',
#   'population': '1,339,330,514',
#   'iso_a2': ' IN',
#   'iso_a3': ' IND'},
#  {'country': 'Indonesia',
#   'happiness score': 5.345,
#   'gdp': 9.365,
#   'social_support': 0.811,
#   'life_expectancy': 62.236,
#   'freedom': 0.873,
#   'generosity': 0.542,
#   'corruption': 0.867,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.954,
#   'contribution_social_support': 0.786,
#   'contribution_life_expectancy': 0.433,
#   'contribution_freedom': 0.598,
#   'contribution_generosity': 0.541,
#   'contribution_corruption': 0.046,
#   'contribution_dystopia': 1.987,
#   'metal_bands_per_100000_people': 0.582,
#   'bands': '1,601',
#   'population': '275,122,131',
#   'iso_a2': ' ID',
#   'iso_a3': ' IDN'},
#  {'country': 'Iran',
#   'happiness score': 4.721,
#   'gdp': 9.584,
#   'social_support': 0.71,
#   'life_expectancy': 66.3,
#   'freedom': 0.608,
#   'generosity': 0.218,
#   'corruption': 0.714,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.03,
#   'contribution_social_support': 0.557,
#   'contribution_life_expectancy': 0.561,
#   'contribution_freedom': 0.275,
#   'contribution_generosity': 0.33,
#   'contribution_corruption': 0.144,
#   'contribution_dystopia': 1.823,
#   'metal_bands_per_100000_people': 0.109,
#   'bands': '94',
#   'population': '85,888,910',
#   'iso_a2': ' IR',
#   'iso_a3': ' IRN'},
#  {'country': 'Iraq',
#   'happiness score': 4.854,
#   'gdp': 9.24,
#   'social_support': 0.746,
#   'life_expectancy': 60.583,
#   'freedom': 0.63,
#   'generosity': -0.053,
#   'corruption': 0.875,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.91,
#   'contribution_social_support': 0.638,
#   'contribution_life_expectancy': 0.381,
#   'contribution_freedom': 0.302,
#   'contribution_generosity': 0.153,
#   'contribution_corruption': 0.041,
#   'contribution_dystopia': 2.429,
#   'metal_bands_per_100000_people': 0.03,
#   'bands': '12',
#   'population': '39,650,145',
#   'iso_a2': ' IQ',
#   'iso_a3': ' IRQ'},
#  {'country': 'Ireland',
#   'happiness score': 7.085,
#   'gdp': 11.342,
#   'social_support': 0.947,
#   'life_expectancy': 72.4,
#   'freedom': 0.879,
#   'generosity': 0.077,
#   'corruption': 0.363,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.644,
#   'contribution_social_support': 1.092,
#   'contribution_life_expectancy': 0.753,
#   'contribution_freedom': 0.606,
#   'contribution_generosity': 0.238,
#   'contribution_corruption': 0.367,
#   'contribution_dystopia': 2.384,
#   'metal_bands_per_100000_people': 4.421,
#   'bands': '231',
#   'population': '5,224,884',
#   'iso_a2': ' IE',
#   'iso_a3': ' IRL'},
#  {'country': 'Israel',
#   'happiness score': 7.157,
#   'gdp': 10.575,
#   'social_support': 0.939,
#   'life_expectancy': 73.503,
#   'freedom': 0.8,
#   'generosity': 0.031,
#   'corruption': 0.753,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.376,
#   'contribution_social_support': 1.074,
#   'contribution_life_expectancy': 0.788,
#   'contribution_freedom': 0.509,
#   'contribution_generosity': 0.208,
#   'contribution_corruption': 0.119,
#   'contribution_dystopia': 3.083,
#   'metal_bands_per_100000_people': 1.878,
#   'bands': '165',
#   'population': '8,787,045',
#   'iso_a2': ' IL',
#   'iso_a3': ' ISR'},
#  {'country': 'Italy',
#   'happiness score': 6.483,
#   'gdp': 10.623,
#   'social_support': 0.88,
#   'life_expectancy': 73.8,
#   'freedom': 0.693,
#   'generosity': -0.084,
#   'corruption': 0.866,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.393,
#   'contribution_social_support': 0.94,
#   'contribution_life_expectancy': 0.798,
#   'contribution_freedom': 0.379,
#   'contribution_generosity': 0.133,
#   'contribution_corruption': 0.047,
#   'contribution_dystopia': 2.794,
#   'metal_bands_per_100000_people': 5.807,
#   'bands': '3,623',
#   'population': '62,390,364',
#   'iso_a2': ' IT',
#   'iso_a3': ' ITA'},
#  {'country': 'Jamaica',
#   'happiness score': 6.309,
#   'gdp': 9.186,
#   'social_support': 0.877,
#   'life_expectancy': 67.5,
#   'freedom': 0.89,
#   'generosity': -0.137,
#   'corruption': 0.884,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.891,
#   'contribution_social_support': 0.932,
#   'contribution_life_expectancy': 0.599,
#   'contribution_freedom': 0.618,
#   'contribution_generosity': 0.099,
#   'contribution_corruption': 0.035,
#   'contribution_dystopia': 3.135,
#   'metal_bands_per_100000_people': 0.071,
#   'bands': '2',
#   'population': '2,816,602',
#   'iso_a2': ' JM',
#   'iso_a3': ' JAM'},
#  {'country': 'Japan',
#   'happiness score': 5.94,
#   'gdp': 10.611,
#   'social_support': 0.884,
#   'life_expectancy': 75.1,
#   'freedom': 0.796,
#   'generosity': -0.258,
#   'corruption': 0.638,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.389,
#   'contribution_social_support': 0.949,
#   'contribution_life_expectancy': 0.838,
#   'contribution_freedom': 0.504,
#   'contribution_generosity': 0.02,
#   'contribution_corruption': 0.192,
#   'contribution_dystopia': 2.048,
#   'metal_bands_per_100000_people': 1.057,
#   'bands': '1,318',
#   'population': '124,687,293',
#   'iso_a2': ' JP',
#   'iso_a3': ' JPN'},
#  {'country': 'Jordan',
#   'happiness score': 4.395,
#   'gdp': 9.182,
#   'social_support': 0.767,
#   'life_expectancy': 67.0,
#   'freedom': 0.755,
#   'generosity': -0.167,
#   'corruption': 0.705,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.89,
#   'contribution_social_support': 0.685,
#   'contribution_life_expectancy': 0.583,
#   'contribution_freedom': 0.455,
#   'contribution_generosity': 0.079,
#   'contribution_corruption': 0.15,
#   'contribution_dystopia': 1.553,
#   'metal_bands_per_100000_people': 0.183,
#   'bands': '20',
#   'population': '10,909,567',
#   'iso_a2': ' JO',
#   'iso_a3': ' JOR'},
#  {'country': 'Kazakhstan',
#   'happiness score': 6.152,
#   'gdp': 10.155,
#   'social_support': 0.952,
#   'life_expectancy': 65.2,
#   'freedom': 0.853,
#   'generosity': -0.069,
#   'corruption': 0.733,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.23,
#   'contribution_social_support': 1.103,
#   'contribution_life_expectancy': 0.527,
#   'contribution_freedom': 0.573,
#   'contribution_generosity': 0.143,
#   'contribution_corruption': 0.132,
#   'contribution_dystopia': 2.446,
#   'metal_bands_per_100000_people': 0.13,
#   'bands': '25',
#   'population': '19,245,793',
#   'iso_a2': ' KZ',
#   'iso_a3': ' KAZ'},
#  {'country': 'Kenya',
#   'happiness score': 4.607,
#   'gdp': 8.361,
#   'social_support': 0.688,
#   'life_expectancy': 60.704,
#   'freedom': 0.779,
#   'generosity': 0.287,
#   'corruption': 0.825,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.603,
#   'contribution_social_support': 0.508,
#   'contribution_life_expectancy': 0.385,
#   'contribution_freedom': 0.483,
#   'contribution_generosity': 0.375,
#   'contribution_corruption': 0.073,
#   'contribution_dystopia': 2.18,
#   'metal_bands_per_100000_people': 0.011,
#   'bands': '6',
#   'population': '54,685,051',
#   'iso_a2': ' KE',
#   'iso_a3': ' KEN'},
#  {'country': 'Kuwait',
#   'happiness score': 6.106,
#   'gdp': 10.817,
#   'social_support': 0.843,
#   'life_expectancy': 66.9,
#   'freedom': 0.867,
#   'generosity': -0.104,
#   'corruption': 0.736,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.461,
#   'contribution_social_support': 0.857,
#   'contribution_life_expectancy': 0.58,
#   'contribution_freedom': 0.591,
#   'contribution_generosity': 0.12,
#   'contribution_corruption': 0.13,
#   'contribution_dystopia': 2.368,
#   'metal_bands_per_100000_people': 0.165,
#   'bands': '5',
#   'population': '3,032,065',
#   'iso_a2': ' KW',
#   'iso_a3': ' KWT'},
#  {'country': 'Kyrgyzstan',
#   'happiness score': 5.744,
#   'gdp': 8.538,
#   'social_support': 0.893,
#   'life_expectancy': 64.401,
#   'freedom': 0.935,
#   'generosity': 0.119,
#   'corruption': 0.908,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.665,
#   'contribution_social_support': 0.971,
#   'contribution_life_expectancy': 0.501,
#   'contribution_freedom': 0.673,
#   'contribution_generosity': 0.266,
#   'contribution_corruption': 0.02,
#   'contribution_dystopia': 2.648,
#   'metal_bands_per_100000_people': 0.1,
#   'bands': '6',
#   'population': '6,018,789',
#   'iso_a2': ' KG',
#   'iso_a3': ' KGZ'},
#  {'country': 'Laos',
#   'happiness score': 5.03,
#   'gdp': 8.947,
#   'social_support': 0.728,
#   'life_expectancy': 58.968,
#   'freedom': 0.91,
#   'generosity': 0.123,
#   'corruption': 0.658,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.808,
#   'contribution_social_support': 0.598,
#   'contribution_life_expectancy': 0.33,
#   'contribution_freedom': 0.643,
#   'contribution_generosity': 0.268,
#   'contribution_corruption': 0.179,
#   'contribution_dystopia': 2.204,
#   'metal_bands_per_100000_people': 0.092,
#   'bands': '7',
#   'population': '7,574,356',
#   'iso_a2': ' LA',
#   'iso_a3': ' LAO'},
#  {'country': 'Latvia',
#   'happiness score': 6.032,
#   'gdp': 10.315,
#   'social_support': 0.927,
#   'life_expectancy': 67.1,
#   'freedom': 0.715,
#   'generosity': -0.162,
#   'corruption': 0.8,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.285,
#   'contribution_social_support': 1.047,
#   'contribution_life_expectancy': 0.587,
#   'contribution_freedom': 0.405,
#   'contribution_generosity': 0.082,
#   'contribution_corruption': 0.089,
#   'contribution_dystopia': 2.536,
#   'metal_bands_per_100000_people': 4.456,
#   'bands': '83',
#   'population': '1,862,687',
#   'iso_a2': ' LV',
#   'iso_a3': ' LVA'},
#  {'country': 'Lebanon',
#   'happiness score': 4.584,
#   'gdp': 9.626,
#   'social_support': 0.848,
#   'life_expectancy': 67.355,
#   'freedom': 0.525,
#   'generosity': -0.073,
#   'corruption': 0.898,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.045,
#   'contribution_social_support': 0.868,
#   'contribution_life_expectancy': 0.595,
#   'contribution_freedom': 0.175,
#   'contribution_generosity': 0.14,
#   'contribution_corruption': 0.026,
#   'contribution_dystopia': 1.736,
#   'metal_bands_per_100000_people': 0.475,
#   'bands': '25',
#   'population': '5,261,372',
#   'iso_a2': ' LB',
#   'iso_a3': ' LBN'},
#  {'country': 'Libya',
#   'happiness score': 5.41,
#   'gdp': 9.622,
#   'social_support': 0.827,
#   'life_expectancy': 62.3,
#   'freedom': 0.771,
#   'generosity': -0.087,
#   'corruption': 0.667,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.044,
#   'contribution_social_support': 0.821,
#   'contribution_life_expectancy': 0.435,
#   'contribution_freedom': 0.474,
#   'contribution_generosity': 0.131,
#   'contribution_corruption': 0.174,
#   'contribution_dystopia': 2.331,
#   'metal_bands_per_100000_people': 0.057,
#   'bands': '4',
#   'population': '7,017,224',
#   'iso_a2': ' LY',
#   'iso_a3': ' LBY'},
#  {'country': 'Lithuania',
#   'happiness score': 6.255,
#   'gdp': 10.499,
#   'social_support': 0.935,
#   'life_expectancy': 67.906,
#   'freedom': 0.773,
#   'generosity': -0.203,
#   'corruption': 0.826,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.35,
#   'contribution_social_support': 1.065,
#   'contribution_life_expectancy': 0.612,
#   'contribution_freedom': 0.476,
#   'contribution_generosity': 0.056,
#   'contribution_corruption': 0.073,
#   'contribution_dystopia': 2.624,
#   'metal_bands_per_100000_people': 3.983,
#   'bands': '108',
#   'population': '2,711,566',
#   'iso_a2': ' LT',
#   'iso_a3': ' LTU'},
#  {'country': 'Luxembourg',
#   'happiness score': 7.324,
#   'gdp': 11.647,
#   'social_support': 0.908,
#   'life_expectancy': 72.6,
#   'freedom': 0.907,
#   'generosity': -0.034,
#   'corruption': 0.386,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.751,
#   'contribution_social_support': 1.003,
#   'contribution_life_expectancy': 0.76,
#   'contribution_freedom': 0.639,
#   'contribution_generosity': 0.166,
#   'contribution_corruption': 0.353,
#   'contribution_dystopia': 2.653,
#   'metal_bands_per_100000_people': 5.941,
#   'bands': '38',
#   'population': '639,589',
#   'iso_a2': ' LU',
#   'iso_a3': ' LUX'},
#  {'country': 'North Macedonia',
#   'happiness score': 5.101,
#   'gdp': 9.693,
#   'social_support': 0.805,
#   'life_expectancy': 65.474,
#   'freedom': 0.751,
#   'generosity': 0.038,
#   'corruption': 0.905,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.068,
#   'contribution_social_support': 0.772,
#   'contribution_life_expectancy': 0.535,
#   'contribution_freedom': 0.45,
#   'contribution_generosity': 0.212,
#   'contribution_corruption': 0.022,
#   'contribution_dystopia': 2.042,
#   'metal_bands_per_100000_people': 2.96,
#   'bands': '63',
#   'population': '2,128,262',
#   'iso_a2': ' MK',
#   'iso_a3': ' MKD'},
#  {'country': 'Madagascar',
#   'happiness score': 4.208,
#   'gdp': 7.396,
#   'social_support': 0.686,
#   'life_expectancy': 59.305,
#   'freedom': 0.552,
#   'generosity': -0.005,
#   'corruption': 0.803,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.266,
#   'contribution_social_support': 0.503,
#   'contribution_life_expectancy': 0.341,
#   'contribution_freedom': 0.207,
#   'contribution_generosity': 0.185,
#   'contribution_corruption': 0.087,
#   'contribution_dystopia': 2.62,
#   'metal_bands_per_100000_people': 0.058,
#   'bands': '16',
#   'population': '27,534,354',
#   'iso_a2': ' MG',
#   'iso_a3': ' MDG'},
#  {'country': 'Malaysia',
#   'happiness score': 5.384,
#   'gdp': 10.238,
#   'social_support': 0.817,
#   'life_expectancy': 67.102,
#   'freedom': 0.895,
#   'generosity': 0.125,
#   'corruption': 0.839,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.259,
#   'contribution_social_support': 0.797,
#   'contribution_life_expectancy': 0.587,
#   'contribution_freedom': 0.624,
#   'contribution_generosity': 0.27,
#   'contribution_corruption': 0.064,
#   'contribution_dystopia': 1.784,
#   'metal_bands_per_100000_people': 1.366,
#   'bands': '458',
#   'population': '33,519,406',
#   'iso_a2': ' MY',
#   'iso_a3': ' MYS'},
#  {'country': 'Maldives',
#   'happiness score': 5.198,
#   'gdp': 9.826,
#   'social_support': 0.913,
#   'life_expectancy': 70.6,
#   'freedom': 0.854,
#   'generosity': 0.024,
#   'corruption': 0.825,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.115,
#   'contribution_social_support': 1.015,
#   'contribution_life_expectancy': 0.697,
#   'contribution_freedom': 0.575,
#   'contribution_generosity': 0.204,
#   'contribution_corruption': 0.073,
#   'contribution_dystopia': 1.52,
#   'metal_bands_per_100000_people': 1.536,
#   'bands': '6',
#   'population': '390,669',
#   'iso_a2': ' MV',
#   'iso_a3': ' MDV'},
#  {'country': 'Malta',
#   'happiness score': 6.602,
#   'gdp': 10.674,
#   'social_support': 0.931,
#   'life_expectancy': 72.2,
#   'freedom': 0.927,
#   'generosity': 0.133,
#   'corruption': 0.653,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.411,
#   'contribution_social_support': 1.055,
#   'contribution_life_expectancy': 0.747,
#   'contribution_freedom': 0.664,
#   'contribution_generosity': 0.275,
#   'contribution_corruption': 0.183,
#   'contribution_dystopia': 2.268,
#   'metal_bands_per_100000_people': 11.066,
#   'bands': '51',
#   'population': '460,891',
#   'iso_a2': ' MT',
#   'iso_a3': ' MLT'},
#  {'country': 'Mauritius',
#   'happiness score': 6.049,
#   'gdp': 10.008,
#   'social_support': 0.905,
#   'life_expectancy': 66.701,
#   'freedom': 0.867,
#   'generosity': -0.054,
#   'corruption': 0.789,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.178,
#   'contribution_social_support': 0.996,
#   'contribution_life_expectancy': 0.574,
#   'contribution_freedom': 0.59,
#   'contribution_generosity': 0.153,
#   'contribution_corruption': 0.096,
#   'contribution_dystopia': 2.462,
#   'metal_bands_per_100000_people': 0.144,
#   'bands': '2',
#   'population': '1,386,129',
#   'iso_a2': ' MU',
#   'iso_a3': ' MUS'},
#  {'country': 'Mexico',
#   'happiness score': 6.317,
#   'gdp': 9.859,
#   'social_support': 0.831,
#   'life_expectancy': 68.597,
#   'freedom': 0.862,
#   'generosity': -0.147,
#   'corruption': 0.799,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.126,
#   'contribution_social_support': 0.83,
#   'contribution_life_expectancy': 0.634,
#   'contribution_freedom': 0.585,
#   'contribution_generosity': 0.092,
#   'contribution_corruption': 0.089,
#   'contribution_dystopia': 2.961,
#   'metal_bands_per_100000_people': 1.843,
#   'bands': '2,400',
#   'population': '130,207,371',
#   'iso_a2': ' MX',
#   'iso_a3': ' MEX'},
#  {'country': 'Moldova',
#   'happiness score': 5.766,
#   'gdp': 9.454,
#   'social_support': 0.857,
#   'life_expectancy': 65.699,
#   'freedom': 0.822,
#   'generosity': -0.079,
#   'corruption': 0.918,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.985,
#   'contribution_social_support': 0.888,
#   'contribution_life_expectancy': 0.542,
#   'contribution_freedom': 0.536,
#   'contribution_generosity': 0.137,
#   'contribution_corruption': 0.013,
#   'contribution_dystopia': 2.665,
#   'metal_bands_per_100000_people': 0.752,
#   'bands': '25',
#   'population': '3,323,875',
#   'iso_a2': ' MD',
#   'iso_a3': ' MDA'},
#  {'country': 'Mongolia',
#   'happiness score': 5.677,
#   'gdp': 9.4,
#   'social_support': 0.935,
#   'life_expectancy': 62.5,
#   'freedom': 0.708,
#   'generosity': 0.116,
#   'corruption': 0.856,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.966,
#   'contribution_social_support': 1.065,
#   'contribution_life_expectancy': 0.442,
#   'contribution_freedom': 0.397,
#   'contribution_generosity': 0.263,
#   'contribution_corruption': 0.053,
#   'contribution_dystopia': 2.492,
#   'metal_bands_per_100000_people': 0.156,
#   'bands': '5',
#   'population': '3,198,913',
#   'iso_a2': ' MN',
#   'iso_a3': ' MNG'},
#  {'country': 'Montenegro',
#   'happiness score': 5.581,
#   'gdp': 9.94,
#   'social_support': 0.858,
#   'life_expectancy': 68.699,
#   'freedom': 0.708,
#   'generosity': -0.034,
#   'corruption': 0.812,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.155,
#   'contribution_social_support': 0.891,
#   'contribution_life_expectancy': 0.637,
#   'contribution_freedom': 0.397,
#   'contribution_generosity': 0.166,
#   'contribution_corruption': 0.081,
#   'contribution_dystopia': 2.254,
#   'metal_bands_per_100000_people': 1.482,
#   'bands': '9',
#   'population': '607,414',
#   'iso_a2': ' ME',
#   'iso_a3': ' MNE'},
#  {'country': 'Morocco',
#   'happiness score': 4.918,
#   'gdp': 8.903,
#   'social_support': 0.56,
#   'life_expectancy': 66.208,
#   'freedom': 0.774,
#   'generosity': -0.236,
#   'corruption': 0.801,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.792,
#   'contribution_social_support': 0.219,
#   'contribution_life_expectancy': 0.558,
#   'contribution_freedom': 0.477,
#   'contribution_generosity': 0.034,
#   'contribution_corruption': 0.088,
#   'contribution_dystopia': 2.749,
#   'metal_bands_per_100000_people': 0.06,
#   'bands': '22',
#   'population': '36,561,813',
#   'iso_a2': ' MA',
#   'iso_a3': ' MAR'},
#  {'country': 'Mozambique',
#   'happiness score': 4.794,
#   'gdp': 7.158,
#   'social_support': 0.744,
#   'life_expectancy': 54.706,
#   'freedom': 0.882,
#   'generosity': 0.061,
#   'corruption': 0.684,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.183,
#   'contribution_social_support': 0.634,
#   'contribution_life_expectancy': 0.196,
#   'contribution_freedom': 0.608,
#   'contribution_generosity': 0.228,
#   'contribution_corruption': 0.163,
#   'contribution_dystopia': 2.783,
#   'metal_bands_per_100000_people': 0.003,
#   'bands': '1',
#   'population': '30,888,034',
#   'iso_a2': ' MZ',
#   'iso_a3': ' MOZ'},
#  {'country': 'Namibia',
#   'happiness score': 4.574,
#   'gdp': 9.161,
#   'social_support': 0.818,
#   'life_expectancy': 56.799,
#   'freedom': 0.719,
#   'generosity': -0.149,
#   'corruption': 0.847,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.882,
#   'contribution_social_support': 0.801,
#   'contribution_life_expectancy': 0.262,
#   'contribution_freedom': 0.411,
#   'contribution_generosity': 0.091,
#   'contribution_corruption': 0.059,
#   'contribution_dystopia': 2.068,
#   'metal_bands_per_100000_people': 0.037,
#   'bands': '1',
#   'population': '2,678,191',
#   'iso_a2': ' NA',
#   'iso_a3': ' NAM'},
#  {'country': 'Nepal',
#   'happiness score': 5.269,
#   'gdp': 8.12,
#   'social_support': 0.774,
#   'life_expectancy': 64.233,
#   'freedom': 0.782,
#   'generosity': 0.152,
#   'corruption': 0.727,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.519,
#   'contribution_social_support': 0.702,
#   'contribution_life_expectancy': 0.496,
#   'contribution_freedom': 0.488,
#   'contribution_generosity': 0.287,
#   'contribution_corruption': 0.135,
#   'contribution_dystopia': 2.642,
#   'metal_bands_per_100000_people': 0.076,
#   'bands': '23',
#   'population': '30,424,878',
#   'iso_a2': ' NP',
#   'iso_a3': ' NPL'},
#  {'country': 'Netherlands',
#   'happiness score': 7.464,
#   'gdp': 10.932,
#   'social_support': 0.942,
#   'life_expectancy': 72.4,
#   'freedom': 0.913,
#   'generosity': 0.175,
#   'corruption': 0.338,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.501,
#   'contribution_social_support': 1.079,
#   'contribution_life_expectancy': 0.753,
#   'contribution_freedom': 0.647,
#   'contribution_generosity': 0.302,
#   'contribution_corruption': 0.384,
#   'contribution_dystopia': 2.798,
#   'metal_bands_per_100000_people': 6.252,
#   'bands': '1,084',
#   'population': '17,337,403',
#   'iso_a2': ' NL',
#   'iso_a3': ' NLD'},
#  {'country': 'New Zealand',
#   'happiness score': 7.277,
#   'gdp': 10.643,
#   'social_support': 0.948,
#   'life_expectancy': 73.4,
#   'freedom': 0.929,
#   'generosity': 0.134,
#   'corruption': 0.242,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.4,
#   'contribution_social_support': 1.094,
#   'contribution_life_expectancy': 0.785,
#   'contribution_freedom': 0.665,
#   'contribution_generosity': 0.276,
#   'contribution_corruption': 0.445,
#   'contribution_dystopia': 2.612,
#   'metal_bands_per_100000_people': 5.77,
#   'bands': '288',
#   'population': '4,991,442',
#   'iso_a2': ' NZ',
#   'iso_a3': ' NZL'},
#  {'country': 'Nicaragua',
#   'happiness score': 5.972,
#   'gdp': 8.62,
#   'social_support': 0.864,
#   'life_expectancy': 67.657,
#   'freedom': 0.836,
#   'generosity': 0.02,
#   'corruption': 0.664,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.693,
#   'contribution_social_support': 0.904,
#   'contribution_life_expectancy': 0.604,
#   'contribution_freedom': 0.553,
#   'contribution_generosity': 0.201,
#   'contribution_corruption': 0.176,
#   'contribution_dystopia': 2.841,
#   'metal_bands_per_100000_people': 0.561,
#   'bands': '35',
#   'population': '6,243,931',
#   'iso_a2': ' NI',
#   'iso_a3': ' NIC'},
#  {'country': 'Norway',
#   'happiness score': 7.392,
#   'gdp': 11.053,
#   'social_support': 0.954,
#   'life_expectancy': 73.3,
#   'freedom': 0.96,
#   'generosity': 0.093,
#   'corruption': 0.27,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.543,
#   'contribution_social_support': 1.108,
#   'contribution_life_expectancy': 0.782,
#   'contribution_freedom': 0.703,
#   'contribution_generosity': 0.249,
#   'contribution_corruption': 0.427,
#   'contribution_dystopia': 2.58,
#   'metal_bands_per_100000_people': 18.277,
#   'bands': '1,007',
#   'population': '5,509,591',
#   'iso_a2': ' NO',
#   'iso_a3': ' NOR'},
#  {'country': 'Pakistan',
#   'happiness score': 4.934,
#   'gdp': 8.458,
#   'social_support': 0.651,
#   'life_expectancy': 58.709,
#   'freedom': 0.726,
#   'generosity': 0.098,
#   'corruption': 0.787,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.637,
#   'contribution_social_support': 0.423,
#   'contribution_life_expectancy': 0.322,
#   'contribution_freedom': 0.418,
#   'contribution_generosity': 0.252,
#   'contribution_corruption': 0.097,
#   'contribution_dystopia': 2.784,
#   'metal_bands_per_100000_people': 0.008,
#   'bands': '19',
#   'population': '238,181,034',
#   'iso_a2': ' PK',
#   'iso_a3': ' PAK'},
#  {'country': 'Panama',
#   'happiness score': 6.18,
#   'gdp': 10.35,
#   'social_support': 0.896,
#   'life_expectancy': 69.652,
#   'freedom': 0.872,
#   'generosity': -0.166,
#   'corruption': 0.856,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.298,
#   'contribution_social_support': 0.976,
#   'contribution_life_expectancy': 0.667,
#   'contribution_freedom': 0.596,
#   'contribution_generosity': 0.079,
# ...
#   'population': '21,230,362',
#   'iso_a2': ' RO',
#   'iso_a3': ' ROU'},
#  {'country': 'Russia',
#   'happiness score': 5.477,
#   'gdp': 10.189,
#   'social_support': 0.903,
#   'life_expectancy': 64.703,
#   'freedom': 0.718,
#   'generosity': -0.111,
#   'corruption': 0.845,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.241,
#   'contribution_social_support': 0.992,
#   'contribution_life_expectancy': 0.511,
#   'contribution_freedom': 0.409,
#   'contribution_generosity': 0.115,
#   'contribution_corruption': 0.06,
#   'contribution_dystopia': 2.148,
#   'metal_bands_per_100000_people': 2.159,
#   'bands': '3,072',
#   'population': '142,320,790',
#   'iso_a2': ' RU',
#   'iso_a3': ' RUS'},
#  {'country': 'Saudi Arabia',
#   'happiness score': 6.494,
#   'gdp': 10.743,
#   'social_support': 0.891,
#   'life_expectancy': 66.603,
#   'freedom': 0.877,
#   'generosity': -0.149,
#   'corruption': 0.684,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.435,
#   'contribution_social_support': 0.964,
#   'contribution_life_expectancy': 0.571,
#   'contribution_freedom': 0.603,
#   'contribution_generosity': 0.09,
#   'contribution_corruption': 0.163,
#   'contribution_dystopia': 2.668,
#   'metal_bands_per_100000_people': 0.026,
#   'bands': '9',
#   'population': '34,783,757',
#   'iso_a2': ' SA',
#   'iso_a3': ' SAU'},
#  {'country': 'Serbia',
#   'happiness score': 6.078,
#   'gdp': 9.787,
#   'social_support': 0.873,
#   'life_expectancy': 68.6,
#   'freedom': 0.778,
#   'generosity': 0.002,
#   'corruption': 0.835,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.101,
#   'contribution_social_support': 0.924,
#   'contribution_life_expectancy': 0.634,
#   'contribution_freedom': 0.482,
#   'contribution_generosity': 0.189,
#   'contribution_corruption': 0.066,
#   'contribution_dystopia': 2.682,
#   'metal_bands_per_100000_people': 4.086,
#   'bands': '285',
#   'population': '6,974,289',
#   'iso_a2': ' RS',
#   'iso_a3': ' SRB'},
#  {'country': 'Singapore',
#   'happiness score': 6.377,
#   'gdp': 11.488,
#   'social_support': 0.915,
#   'life_expectancy': 76.953,
#   'freedom': 0.927,
#   'generosity': -0.018,
#   'corruption': 0.082,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.695,
#   'contribution_social_support': 1.019,
#   'contribution_life_expectancy': 0.897,
#   'contribution_freedom': 0.664,
#   'contribution_generosity': 0.176,
#   'contribution_corruption': 0.547,
#   'contribution_dystopia': 1.379,
#   'metal_bands_per_100000_people': 2.949,
#   'bands': '173',
#   'population': '5,866,139',
#   'iso_a2': ' SG',
#   'iso_a3': ' SGP'},
#  {'country': 'Slovakia',
#   'happiness score': 6.331,
#   'gdp': 10.369,
#   'social_support': 0.936,
#   'life_expectancy': 69.201,
#   'freedom': 0.766,
#   'generosity': -0.124,
#   'corruption': 0.911,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.304,
#   'contribution_social_support': 1.066,
#   'contribution_life_expectancy': 0.653,
#   'contribution_freedom': 0.468,
#   'contribution_generosity': 0.107,
#   'contribution_corruption': 0.018,
#   'contribution_dystopia': 2.714,
#   'metal_bands_per_100000_people': 6.567,
#   'bands': '357',
#   'population': '5,436,066',
#   'iso_a2': ' SK',
#   'iso_a3': ' SVK'},
#  {'country': 'Slovenia',
#   'happiness score': 6.461,
#   'gdp': 10.529,
#   'social_support': 0.948,
#   'life_expectancy': 71.4,
#   'freedom': 0.949,
#   'generosity': -0.101,
#   'corruption': 0.806,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.36,
#   'contribution_social_support': 1.093,
#   'contribution_life_expectancy': 0.722,
#   'contribution_freedom': 0.69,
#   'contribution_generosity': 0.122,
#   'contribution_corruption': 0.085,
#   'contribution_dystopia': 2.388,
#   'metal_bands_per_100000_people': 7.802,
#   'bands': '164',
#   'population': '2,102,106',
#   'iso_a2': ' SI',
#   'iso_a3': ' SVN'},
#  {'country': 'South Africa',
#   'happiness score': 4.956,
#   'gdp': 9.403,
#   'social_support': 0.86,
#   'life_expectancy': 56.904,
#   'freedom': 0.749,
#   'generosity': -0.067,
#   'corruption': 0.86,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.967,
#   'contribution_social_support': 0.895,
#   'contribution_life_expectancy': 0.265,
#   'contribution_freedom': 0.447,
#   'contribution_generosity': 0.144,
#   'contribution_corruption': 0.051,
#   'contribution_dystopia': 2.187,
#   'metal_bands_per_100000_people': 0.29,
#   'bands': '165',
#   'population': '56,978,635',
#   'iso_a2': ' ZA',
#   'iso_a3': ' ZAF'},
#  {'country': 'South Korea',
#   'happiness score': 5.845,
#   'gdp': 10.651,
#   'social_support': 0.799,
#   'life_expectancy': 73.9,
#   'freedom': 0.672,
#   'generosity': -0.083,
#   'corruption': 0.727,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.403,
#   'contribution_social_support': 0.758,
#   'contribution_life_expectancy': 0.801,
#   'contribution_freedom': 0.353,
#   'contribution_generosity': 0.134,
#   'contribution_corruption': 0.135,
#   'contribution_dystopia': 2.262,
#   'metal_bands_per_100000_people': 0.282,
#   'bands': '146',
#   'population': '51,715,162',
#   'iso_a2': ' KR',
#   'iso_a3': ' KOR'},
#  {'country': 'Spain',
#   'happiness score': 6.491,
#   'gdp': 10.571,
#   'social_support': 0.932,
#   'life_expectancy': 74.7,
#   'freedom': 0.761,
#   'generosity': -0.081,
#   'corruption': 0.745,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.375,
#   'contribution_social_support': 1.057,
#   'contribution_life_expectancy': 0.826,
#   'contribution_freedom': 0.462,
#   'contribution_generosity': 0.135,
#   'contribution_corruption': 0.124,
#   'contribution_dystopia': 2.513,
#   'metal_bands_per_100000_people': 4.236,
#   'bands': '2,002',
#   'population': '47,260,584',
#   'iso_a2': ' ES',
#   'iso_a3': ' ESP'},
#  {'country': 'Sri Lanka',
#   'happiness score': 4.325,
#   'gdp': 9.47,
#   'social_support': 0.827,
#   'life_expectancy': 67.299,
#   'freedom': 0.841,
#   'generosity': 0.079,
#   'corruption': 0.863,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.99,
#   'contribution_social_support': 0.82,
#   'contribution_life_expectancy': 0.593,
#   'contribution_freedom': 0.559,
#   'contribution_generosity': 0.239,
#   'contribution_corruption': 0.049,
#   'contribution_dystopia': 1.075,
#   'metal_bands_per_100000_people': 0.13,
#   'bands': '30',
#   'population': '23,044,123',
#   'iso_a2': ' LK',
#   'iso_a3': ' LKA'},
#  {'country': 'Sweden',
#   'happiness score': 7.363,
#   'gdp': 10.867,
#   'social_support': 0.934,
#   'life_expectancy': 72.7,
#   'freedom': 0.945,
#   'generosity': 0.086,
#   'corruption': 0.237,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.478,
#   'contribution_social_support': 1.062,
#   'contribution_life_expectancy': 0.763,
#   'contribution_freedom': 0.685,
#   'contribution_generosity': 0.244,
#   'contribution_corruption': 0.448,
#   'contribution_dystopia': 2.683,
#   'metal_bands_per_100000_people': 22.228,
#   'bands': '2,281',
#   'population': '10,261,767',
#   'iso_a2': ' SE',
#   'iso_a3': ' SWE'},
#  {'country': 'Switzerland',
#   'happiness score': 7.571,
#   'gdp': 11.117,
#   'social_support': 0.942,
#   'life_expectancy': 74.4,
#   'freedom': 0.919,
#   'generosity': 0.025,
#   'corruption': 0.292,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.566,
#   'contribution_social_support': 1.079,
#   'contribution_life_expectancy': 0.816,
#   'contribution_freedom': 0.653,
#   'contribution_generosity': 0.204,
#   'contribution_corruption': 0.413,
#   'contribution_dystopia': 2.839,
#   'metal_bands_per_100000_people': 7.452,
#   'bands': '630',
#   'population': '8,453,550',
#   'iso_a2': ' CH',
#   'iso_a3': ' CHE'},
#  {'country': 'Tajikistan',
#   'happiness score': 5.466,
#   'gdp': 8.091,
#   'social_support': 0.86,
#   'life_expectancy': 64.281,
#   'freedom': 0.832,
#   'generosity': -0.056,
#   'corruption': 0.553,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.508,
#   'contribution_social_support': 0.895,
#   'contribution_life_expectancy': 0.498,
#   'contribution_freedom': 0.548,
#   'contribution_generosity': 0.152,
#   'contribution_corruption': 0.247,
#   'contribution_dystopia': 2.619,
#   'metal_bands_per_100000_people': 0.033,
#   'bands': '3',
#   'population': '8,990,874',
#   'iso_a2': ' TJ',
#   'iso_a3': ' TJK'},
#  {'country': 'Thailand',
#   'happiness score': 5.985,
#   'gdp': 9.805,
#   'social_support': 0.888,
#   'life_expectancy': 67.401,
#   'freedom': 0.884,
#   'generosity': 0.287,
#   'corruption': 0.895,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.107,
#   'contribution_social_support': 0.957,
#   'contribution_life_expectancy': 0.596,
#   'contribution_freedom': 0.611,
#   'contribution_generosity': 0.375,
#   'contribution_corruption': 0.028,
#   'contribution_dystopia': 2.309,
#   'metal_bands_per_100000_people': 0.19,
#   'bands': '132',
#   'population': '69,480,520',
#   'iso_a2': ' TH',
#   'iso_a3': ' THA'},
#  {'country': 'Tunisia',
#   'happiness score': 4.596,
#   'gdp': 9.266,
#   'social_support': 0.691,
#   'life_expectancy': 67.201,
#   'freedom': 0.656,
#   'generosity': -0.201,
#   'corruption': 0.87,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.919,
#   'contribution_social_support': 0.515,
#   'contribution_life_expectancy': 0.59,
#   'contribution_freedom': 0.334,
#   'contribution_generosity': 0.057,
#   'contribution_corruption': 0.044,
#   'contribution_dystopia': 2.138,
#   'metal_bands_per_100000_people': 0.212,
#   'bands': '25',
#   'population': '11,811,335',
#   'iso_a2': ' TN',
#   'iso_a3': ' TUN'},
#  {'country': 'Turkey',
#   'happiness score': 4.948,
#   'gdp': 10.24,
#   'social_support': 0.822,
#   'life_expectancy': 67.199,
#   'freedom': 0.576,
#   'generosity': -0.139,
#   'corruption': 0.776,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.26,
#   'contribution_social_support': 0.809,
#   'contribution_life_expectancy': 0.59,
#   'contribution_freedom': 0.236,
#   'contribution_generosity': 0.097,
#   'contribution_corruption': 0.104,
#   'contribution_dystopia': 1.852,
#   'metal_bands_per_100000_people': 0.399,
#   'bands': '329',
#   'population': '82,482,383',
#   'iso_a2': ' TR',
#   'iso_a3': ' TUR'},
#  {'country': 'Turkmenistan',
#   'happiness score': 5.066,
#   'gdp': 9.629,
#   'social_support': 0.983,
#   'life_expectancy': 62.409,
#   'freedom': 0.877,
#   'generosity': 0.273,
#   'corruption': 0.888,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.046,
#   'contribution_social_support': 1.172,
#   'contribution_life_expectancy': 0.439,
#   'contribution_freedom': 0.602,
#   'contribution_generosity': 0.366,
#   'contribution_corruption': 0.033,
#   'contribution_dystopia': 1.409,
#   'metal_bands_per_100000_people': 0.036,
#   'bands': '2',
#   'population': '5,579,889',
#   'iso_a2': ' TM',
#   'iso_a3': ' TKM'},
#  {'country': 'Uganda',
#   'happiness score': 4.636,
#   'gdp': 7.677,
#   'social_support': 0.781,
#   'life_expectancy': 56.101,
#   'freedom': 0.709,
#   'generosity': 0.122,
#   'corruption': 0.855,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.364,
#   'contribution_social_support': 0.718,
#   'contribution_life_expectancy': 0.24,
#   'contribution_freedom': 0.398,
#   'contribution_generosity': 0.267,
#   'contribution_corruption': 0.054,
#   'contribution_dystopia': 2.596,
#   'metal_bands_per_100000_people': 0.004,
#   'bands': '2',
#   'population': '44,712,143',
#   'iso_a2': ' UG',
#   'iso_a3': ' UGA'},
#  {'country': 'Ukraine',
#   'happiness score': 4.875,
#   'gdp': 9.436,
#   'social_support': 0.888,
#   'life_expectancy': 64.902,
#   'freedom': 0.724,
#   'generosity': -0.011,
#   'corruption': 0.924,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.979,
#   'contribution_social_support': 0.958,
#   'contribution_life_expectancy': 0.517,
#   'contribution_freedom': 0.417,
#   'contribution_generosity': 0.181,
#   'contribution_corruption': 0.01,
#   'contribution_dystopia': 1.813,
#   'metal_bands_per_100000_people': 1.634,
#   'bands': '715',
#   'population': '43,745,640',
#   'iso_a2': ' UA',
#   'iso_a3': ' UKR'},
#  {'country': 'United Arab Emirates',
#   'happiness score': 6.561,
#   'gdp': 11.085,
#   'social_support': 0.844,
#   'life_expectancy': 67.333,
#   'freedom': 0.932,
#   'generosity': 0.074,
#   'corruption': 0.589,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.555,
#   'contribution_social_support': 0.86,
#   'contribution_life_expectancy': 0.594,
#   'contribution_freedom': 0.67,
#   'contribution_generosity': 0.236,
#   'contribution_corruption': 0.223,
#   'contribution_dystopia': 2.422,
#   'metal_bands_per_100000_people': 0.142,
#   'bands': '14',
#   'population': '9,856,612',
#   'iso_a2': ' AE',
#   'iso_a3': ' ARE'},
#  {'country': 'United Kingdom',
#   'happiness score': 7.064,
#   'gdp': 10.707,
#   'social_support': 0.934,
#   'life_expectancy': 72.5,
#   'freedom': 0.859,
#   'generosity': 0.233,
#   'corruption': 0.459,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.423,
#   'contribution_social_support': 1.062,
#   'contribution_life_expectancy': 0.757,
#   'contribution_freedom': 0.58,
#   'contribution_generosity': 0.34,
#   'contribution_corruption': 0.306,
#   'contribution_dystopia': 2.596,
#   'metal_bands_per_100000_people': 4.911,
#   'bands': '3,244',
#   'population': '66,052,076',
#   'iso_a2': ' GB',
#   'iso_a3': ' GBR'},
#  {'country': 'United States',
#   'happiness score': 6.951,
#   'gdp': 11.023,
#   'social_support': 0.92,
#   'life_expectancy': 68.2,
#   'freedom': 0.837,
#   'generosity': 0.098,
#   'corruption': 0.698,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.533,
#   'contribution_social_support': 1.03,
#   'contribution_life_expectancy': 0.621,
#   'contribution_freedom': 0.554,
#   'contribution_generosity': 0.252,
#   'contribution_corruption': 0.154,
#   'contribution_dystopia': 2.807,
#   'metal_bands_per_100000_people': 5.241,
#   'bands': '17,557',
#   'population': '334,998,398',
#   'iso_a2': ' US',
#   'iso_a3': ' USA'},
#  {'country': 'Uruguay',
#   'happiness score': 6.431,
#   'gdp': 9.966,
#   'social_support': 0.925,
#   'life_expectancy': 69.1,
#   'freedom': 0.896,
#   'generosity': -0.092,
#   'corruption': 0.59,
#   'dystopia': 2.43,
#   'contribution_gdp': 1.164,
#   'contribution_social_support': 1.042,
#   'contribution_life_expectancy': 0.649,
#   'contribution_freedom': 0.625,
#   'contribution_generosity': 0.128,
#   'contribution_corruption': 0.223,
#   'contribution_dystopia': 2.6,
#   'metal_bands_per_100000_people': 3.561,
#   'bands': '121',
#   'population': '3,398,239',
#   'iso_a2': ' UY',
#   'iso_a3': ' URY'},
#  {'country': 'Uzbekistan',
#   'happiness score': 6.179,
#   'gdp': 8.836,
#   'social_support': 0.918,
#   'life_expectancy': 65.255,
#   'freedom': 0.97,
#   'generosity': 0.311,
#   'corruption': 0.515,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.769,
#   'contribution_social_support': 1.027,
#   'contribution_life_expectancy': 0.528,
#   'contribution_freedom': 0.716,
#   'contribution_generosity': 0.391,
#   'contribution_corruption': 0.271,
#   'contribution_dystopia': 2.477,
#   'metal_bands_per_100000_people': 0.029,
#   'bands': '9',
#   'population': '30,842,796',
#   'iso_a2': ' UZ',
#   'iso_a3': ' UZB'},
#  {'country': 'Venezuela',
#   'happiness score': 4.892,
#   'gdp': 9.073,
#   'social_support': 0.861,
#   'life_expectancy': 66.7,
#   'freedom': 0.615,
#   'generosity': -0.169,
#   'corruption': 0.827,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.852,
#   'contribution_social_support': 0.897,
#   'contribution_life_expectancy': 0.574,
#   'contribution_freedom': 0.284,
#   'contribution_generosity': 0.078,
#   'contribution_corruption': 0.072,
#   'contribution_dystopia': 2.135,
#   'metal_bands_per_100000_people': 1.18,
#   'bands': '343',
#   'population': '29,069,153',
#   'iso_a2': ' VE',
#   'iso_a3': ' VEN'},
#  {'country': 'Vietnam',
#   'happiness score': 5.411,
#   'gdp': 8.973,
#   'social_support': 0.85,
#   'life_expectancy': 68.034,
#   'freedom': 0.94,
#   'generosity': -0.098,
#   'corruption': 0.796,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.817,
#   'contribution_social_support': 0.873,
#   'contribution_life_expectancy': 0.616,
#   'contribution_freedom': 0.679,
#   'contribution_generosity': 0.124,
#   'contribution_corruption': 0.091,
#   'contribution_dystopia': 2.211,
#   'metal_bands_per_100000_people': 0.02,
#   'bands': '21',
#   'population': '102,789,598',
#   'iso_a2': ' VN',
#   'iso_a3': ' VNM'},
#  {'country': 'Zimbabwe',
#   'happiness score': 3.145,
#   'gdp': 7.943,
#   'social_support': 0.75,
#   'life_expectancy': 56.201,
#   'freedom': 0.677,
#   'generosity': -0.047,
#   'corruption': 0.821,
#   'dystopia': 2.43,
#   'contribution_gdp': 0.457,
#   'contribution_social_support': 0.649,
#   'contribution_life_expectancy': 0.243,
#   'contribution_freedom': 0.359,
#   'contribution_generosity': 0.157,
#   'contribution_corruption': 0.075,
#   'contribution_dystopia': 1.205,
#   'metal_bands_per_100000_people': 0.013,
#   'bands': '2',
#   'population': '14,829,988',
#   'iso_a2': ' ZW',
#   'iso_a3': ' ZWE'}]
